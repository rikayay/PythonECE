# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [4,5,6]
z = [7,8,9]
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)
plt.rcParams["grid.color"] = 'red'
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining all 3 axis
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot')
plt.show()

# %%
import pandas as pd
import numpy as np
class Test:
     def main():
          a = {
               "Name": ["SOHAM","INDRASHISH","TANMOY","KAUSTAV","AQIB"],
               "ROLL NUMBER" : [1,2,3,4,5]
          }
        df = pd.DataFrame(a)  
        print(df)
Test.main()     


import pandas as pd
import numpy as np
class Test():
    def main():
        a = {
            "Name": ["Soham","Indrashish","Tanmoy","Kaaustav","Aquib"],
            "Roll no" : [1,2,3,4,5]
                     
    }
        df = pd.DataFrame(a)
        print(df)
Test.main()
# Out:
#   File <tokenize>:9
#     df = pd.DataFrame(a)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import pandas as pd
import numpy as np
class Test():
    def main():
        a = {
            "Name": ["Soham","Indrashish","Tanmoy","Kaaustav","Aqib"],
            "Roll no" : [1,2,3,4,5]
                     
    }
        df = pd.DataFrame(a)
        print(df)
Test.main()
# Out:
#          Name  Roll no
# 0       Soham        1
# 1  Indrashish        2
# 2      Tanmoy        3
# 3    Kaaustav        4
# 4        Aqib        5
